# %% [markdown]
# <a href="https://colab.research.google.com/github/mantoan-thi/Machine-Learning-Projects-with-Python/blob/main/Intelig%C3%AAncia_Artificial_e_Machine_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Inteligência Artificial e Machine Learning

# %% [markdown]
# Inteligência Artificial

# %% [markdown]
# A Inteligência Artificial é uma área ampla dentro da Ciência da Computação que faz com que os computadores desenvolvam a capacidade de compreender e aprender, agindo de forma semelhante à inteligência humana. É como se um programa de computador tentasse imitar o cérebro e seu processo de aprendizagem para agir por conta própria, de forma independente.
#
# Aqui, podemos entender “inteligência” como a capacidade de tomar a decisão certa com base em um conjunto de informações e uma variedade de ações possíveis. É também um conjunto de propriedades da mente, como capacidade de planejar, resolver problemas e raciocinar.
#
# Os sistemas de IA possuem essa capacidade, em maior ou menor grau, dependendo da sofisticação com que são desenvolvidos. Em seguida abordaremos mais a fundo o seu funcionamento, mas antes precisamos abordar outro ponto importante.

# %% [markdown]
# Machine Learning

# %% [markdown]
# O conceito por trás de Machine Learning - ou Aprendizado de Máquina - é alimentar as máquinas com dados e permitir que aprendam por conta própria, sem qualquer intervenção humana no processo de aprendizagem.
#
# Vamos a uma analogia: consideremos que você se inscreveu para fazer aulas de natação e será sua primeira vez em uma piscina. Você nunca nadou antes. No início seu desempenho seria ruim porque não tem ideia de como nadar, mas fica cada vez melhor à medida que observa o professor e os colegas, coleta mais informações e continua praticando.
#
# A observação é apenas outra forma de coleta de dados. Assim como nós, humanos, aprendemos com nossas observações e experiências, as máquinas também são capazes de aprender por conta própria quando são alimentadas com uma boa quantidade de dados. Esse é o Aprendizado de Máquina, o processo de fazer com que as máquinas aprendam e melhorem com a experiência sem serem programadas.

# %% [markdown]
# #AI x ML: qual a diferença?

# %% [markdown]
# AI é uma tecnologia que tem como objetivo criar sistemas inteligentes que podem simular a inteligência humana. Em contraste, o aprendizado de máquina é uma dessas maneiras pelas quais os sistemas podem ser feitos para adquirir uma forma particular de inteligência humana.
#
# Machine Learning é um subconjunto de IA. O objetivo é aprender com os dados e ser capaz de prever resultados quando novos dados forem apresentados ou apenas descobrir os padrões ocultos em dados não rotulados. Já IA tem o objetivo de simular a inteligência humana para resolver problemas complexos.
#
# Apesar da diferença, esses termos são frequentemente usados de forma intercambiável. Portanto, é importante conhecer as principais diferenças. A IA geralmente emprega ML com seus outros subconjuntos, por exemplo, Processamento de Linguagem Natural (PNL) para resolver um problema como a classificação de texto.

# %% [markdown]
# A figura abaixo mostra a relação entre Data Science, AI e Machine Learning, com ML sendo uma intersecção entre AI e Data Science.

# %% [markdown]
# ![ml-ai-ds.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Exemplo

# %% [markdown]
# Referência: https://www.kaggle.com/uciml/iris
#
# O conjunto de dados Iris foi usado no artigo clássico de 1936 de RA Fisher, The Use of Multiple Measurements in Taxonomic Problems , e também pode ser encontrado no UCI Machine Learning Repository .
#
# Inclui três espécies de íris com 50 amostras cada, bem como algumas propriedades sobre cada flor. Uma espécie de flor é linearmente separável das outras duas, mas as outras duas não são linearmente separáveis ​​uma da outra.
#
# As colunas neste conjunto de dados são:
#
# Identificação
# SepalLengthCm
# SepalWidthCm
# PetalLengthCm
# PetalWidthCm
# Espécies

# %%
# Begin by importing all necessary libraries
import pandas as pd

# %%
# Carregando dataset
df = pd.read_csv('/content/Iris.csv',sep=',')

# %%
# Verificando o tamanho do dataset
df.shape
# Out:
# (150, 6)

# %%
# Visualizando
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# Chasses
df['Species'].value_counts()
# Out:
# Iris-versicolor    50
# Iris-setosa        50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
# Define the features 
X = df[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']].values
# Now let's tell the dataframe which column we want for the target/labels.
y =df['Species'].values

# %%
# Test size specifies how much of the data you want to set aside for the testing set. 
# Random_state parameter is just a random seed we can use.
# You can use it if you'd like to reproduce these specific results.
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=27)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler().fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

# %%
# Now we can instantiate the models.
# Let's try using two classifiers, a Support Vector Classifier and a K-Nearest Neighbors Classifier:
# https://scikit-learn.org/stable/modules/svm.html
# https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html
SVC_model = SVC()
# KNN model requires you to specify n_neighbors,
# the number of points the classifier will look at to determine what class a new point belongs to
KNN_model = KNeighborsClassifier(n_neighbors=5)

# %%
# Now let's fit the classifiers:
SVC_model.fit(X_train, y_train),KNN_model.fit(X_train, y_train)
# Out:
# (SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#      decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#      max_iter=-1, probability=False, random_state=None, shrinking=True,
#      tol=0.001, verbose=False),
#  KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                       metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                       weights='uniform'))

# %%
# The call has trained the model, so now we can predict and store the prediction in a variable:
SVC_prediction = SVC_model.predict(X_test)
KNN_prediction = KNN_model.predict(X_test)

# %%
# In Scikit-Learn you just pass in the predictions against the ground truth labels which were stored in your test labels:
# Accuracy score is the simplest way to evaluate
# https://scikit-learn.org/stable/modules/model_evaluation.html#classification-report
# precision é a capacidade do classificador de não rotular como positiva uma amostra negativa, 
# recall é a capacidade do classificador de encontrar todas as amostras positivas.

print('Model SVC: ',accuracy_score(SVC_prediction, y_test))
print('Model KNN: ',accuracy_score(KNN_prediction, y_test))
# But Confusion Matrix and Classification Report give more details about performance
#print(confusion_matrix(SVC_prediction, y_test))
print(classification_report(SVC_prediction, y_test))
# Out:
# Model SVC:  0.94
# Model KNN:  0.92
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        13
# Iris-versicolor       0.94      0.89      0.92        19
#  Iris-virginica       0.89      0.94      0.92        18
#
#        accuracy                           0.94        50
#       macro avg       0.95      0.95      0.95        50
#    weighted avg       0.94      0.94      0.94        50

# %% [markdown]
#  Como fazer previsões?

# %%
X_test[10],y_test[10]
# Out:
# (array([-0.20068674, -0.76619529,  0.34636504,  0.19700183]),
#  'Iris-versicolor')

# %%
print('Modelo SVC: ', SVC_model.predict(X_test[10].reshape(-1, 4))[0])
print('Modelo KNN: ', KNN_model.predict(X_test[10].reshape(-1, 4))[0])
# Out:
# Modelo SVC:  Iris-versicolor
# Modelo KNN:  Iris-versicolor

# %% [markdown]
# # IA

# %%
import tensorflow  as tf
import pandas as pd
import numpy as np

# %%
# Carregando dataset
df = pd.read_csv('/content/Iris.csv',sep=',')

# %%
def Feature(x):
  if x == 'Iris-virginica':
    return 0 
  if x == 'Iris-setosa':
    return 1
  if x == 'Iris-versicolor':
    return 2

# %%
# Define the features 
df['Species'] = df['Species'].apply(lambda x: Feature(x))
y = df['Species']
X = df[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]

# %%
# Test size specifies how much of the data you want to set aside for the testing set. 
# Random_state parameter is just a random seed we can use.
# You can use it if you'd like to reproduce these specific results.
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=27)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler().fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(units=32,activation='relu',input_shape=(4,)))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.Dense(units=64,activation = "relu"))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.Dense(units=32,activation = "relu"))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.Dense(units=3,activation='softmax'))
model.compile(
            optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
            loss='sparse_categorical_crossentropy',
            metrics=['sparse_categorical_accuracy'],
            run_eagerly=True)

# %%
model.summary()
# Out:
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_51 (Dense)             (None, 32)                160
# _________________________________________________________________
# dropout_37 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_52 (Dense)             (None, 64)                2112
# _________________________________________________________________
# dropout_38 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_53 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dropout_39 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_54 (Dense)             (None, 3)                 99
# =================================================================
# Total params: 4,451
# Trainable params: 4,451
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train,y_train,epochs=100,verbose=1)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0136 - sparse_categorical_accuracy: 1.0000
# Epoch 2/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0040 - sparse_categorical_accuracy: 1.0000
# Epoch 3/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0038 - sparse_categorical_accuracy: 1.0000
# Epoch 4/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0022 - sparse_categorical_accuracy: 1.0000
# Epoch 5/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0016 - sparse_categorical_accuracy: 1.0000
# Epoch 6/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0017 - sparse_categorical_accuracy: 1.0000
# Epoch 7/100
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0105 - sparse_categorical_accuracy: 1.0000
# Epoch 8/100
# 3/3 [==============================] - 0s 22ms/step - loss: 8.2450e-04 - sparse_categorical_accuracy: 1.0000
# Epoch 9/100
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0022 - sparse_categorical_accuracy: 1.0000
# Epoch 10/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0083 - sparse_categorical_accuracy: 1.0000
# Epoch 11/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0090 - sparse_categorical_accuracy: 1.0000
# Epoch 12/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0365 - sparse_categorical_accuracy: 0.9867
# Epoch 13/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0196 - sparse_categorical_accuracy: 0.9867
# Epoch 14/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0035 - sparse_categorical_accuracy: 1.0000
# Epoch 15/100
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0084 - sparse_categorical_accuracy: 1.0000
# Epoch 16/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0059 - sparse_categorical_accuracy: 1.0000
# Epoch 17/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0052 - sparse_categorical_accuracy: 1.0000
# Epoch 18/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0696 - sparse_categorical_accuracy: 0.9867
# Epoch 19/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0225 - sparse_categorical_accuracy: 0.9867
# Epoch 20/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2612 - sparse_categorical_accuracy: 0.9733
# Epoch 21/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1161 - sparse_categorical_accuracy: 0.9467
# Epoch 22/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1092 - sparse_categorical_accuracy: 0.9467
# Epoch 23/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0515 - sparse_categorical_accuracy: 0.9867
# Epoch 24/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0539 - sparse_categorical_accuracy: 0.9600
# Epoch 25/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0503 - sparse_categorical_accuracy: 0.9867
# Epoch 26/100
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0645 - sparse_categorical_accuracy: 0.9733
# Epoch 27/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0150 - sparse_categorical_accuracy: 0.9867
# Epoch 28/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1000 - sparse_categorical_accuracy: 0.9867
# Epoch 29/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0705 - sparse_categorical_accuracy: 0.9733
# Epoch 30/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0165 - sparse_categorical_accuracy: 1.0000
# Epoch 31/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0133 - sparse_categorical_accuracy: 1.0000
# Epoch 32/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0087 - sparse_categorical_accuracy: 1.0000
# Epoch 33/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0402 - sparse_categorical_accuracy: 0.9867
# Epoch 34/100
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0138 - sparse_categorical_accuracy: 1.0000
# Epoch 35/100
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0057 - sparse_categorical_accuracy: 1.0000
# Epoch 36/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0061 - sparse_categorical_accuracy: 1.0000
# Epoch 37/100
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0133 - sparse_categorical_accuracy: 1.0000
# Epoch 38/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0053 - sparse_categorical_accuracy: 1.0000
# Epoch 39/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0052 - sparse_categorical_accuracy: 1.0000
# Epoch 40/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0069 - sparse_categorical_accuracy: 1.0000
# Epoch 41/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0071 - sparse_categorical_accuracy: 1.0000
# Epoch 42/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0195 - sparse_categorical_accuracy: 1.0000
# Epoch 43/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0197 - sparse_categorical_accuracy: 0.9867
# Epoch 44/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0035 - sparse_categorical_accuracy: 1.0000
# Epoch 45/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0018 - sparse_categorical_accuracy: 1.0000
# Epoch 46/100
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0027 - sparse_categorical_accuracy: 1.0000
# Epoch 47/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0069 - sparse_categorical_accuracy: 1.0000
# Epoch 48/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0022 - sparse_categorical_accuracy: 1.0000
# Epoch 49/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0043 - sparse_categorical_accuracy: 1.0000
# Epoch 50/100
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0616 - sparse_categorical_accuracy: 0.9867
# Epoch 51/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0034 - sparse_categorical_accuracy: 1.0000
# Epoch 52/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0184 - sparse_categorical_accuracy: 1.0000
# Epoch 53/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0448 - sparse_categorical_accuracy: 0.9867
# Epoch 54/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0050 - sparse_categorical_accuracy: 1.0000
# Epoch 55/100
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0573 - sparse_categorical_accuracy: 0.9867
# Epoch 56/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0023 - sparse_categorical_accuracy: 1.0000
# Epoch 57/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0085 - sparse_categorical_accuracy: 1.0000
# Epoch 58/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0354 - sparse_categorical_accuracy: 0.9867
# Epoch 59/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0097 - sparse_categorical_accuracy: 1.0000
# Epoch 60/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0131 - sparse_categorical_accuracy: 1.0000
# Epoch 61/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1140 - sparse_categorical_accuracy: 0.9733
# Epoch 62/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0401 - sparse_categorical_accuracy: 0.9733
# Epoch 63/100
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0074 - sparse_categorical_accuracy: 1.0000
# Epoch 64/100
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0021 - sparse_categorical_accuracy: 1.0000
# Epoch 65/100
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0025 - sparse_categorical_accuracy: 1.0000
# Epoch 66/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0919 - sparse_categorical_accuracy: 0.9733
# Epoch 67/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0386 - sparse_categorical_accuracy: 0.9733
# Epoch 68/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0329 - sparse_categorical_accuracy: 0.9733
# Epoch 69/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0497 - sparse_categorical_accuracy: 0.9867
# Epoch 70/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0318 - sparse_categorical_accuracy: 0.9733
# Epoch 71/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0050 - sparse_categorical_accuracy: 1.0000
# Epoch 72/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0117 - sparse_categorical_accuracy: 1.0000
# Epoch 73/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0286 - sparse_categorical_accuracy: 0.9867
# Epoch 74/100
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0369 - sparse_categorical_accuracy: 0.9867
# Epoch 75/100
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0055 - sparse_categorical_accuracy: 1.0000
# Epoch 76/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0095 - sparse_categorical_accuracy: 1.0000
# Epoch 77/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0010 - sparse_categorical_accuracy: 1.0000
# Epoch 78/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0626 - sparse_categorical_accuracy: 0.9867
# Epoch 79/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0024 - sparse_categorical_accuracy: 1.0000
# Epoch 80/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0149 - sparse_categorical_accuracy: 1.0000
# Epoch 81/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0112 - sparse_categorical_accuracy: 1.0000
# Epoch 82/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0185 - sparse_categorical_accuracy: 0.9867
# Epoch 83/100
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0177 - sparse_categorical_accuracy: 0.9867
# Epoch 84/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0014 - sparse_categorical_accuracy: 1.0000
# Epoch 85/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0307 - sparse_categorical_accuracy: 0.9867
# Epoch 86/100
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0039 - sparse_categorical_accuracy: 1.0000
# Epoch 87/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0673 - sparse_categorical_accuracy: 0.9867
# Epoch 88/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0063 - sparse_categorical_accuracy: 1.0000
# Epoch 89/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0172 - sparse_categorical_accuracy: 0.9867
# Epoch 90/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0065 - sparse_categorical_accuracy: 1.0000
# Epoch 91/100
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0084 - sparse_categorical_accuracy: 1.0000
# Epoch 92/100
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0039 - sparse_categorical_accuracy: 1.0000
# Epoch 93/100
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0020 - sparse_categorical_accuracy: 1.0000
# Epoch 94/100
# 3/3 [==============================] - 0s 20ms/step - loss: 9.6787e-04 - sparse_categorical_accuracy: 1.0000
# Epoch 95/100
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0024 - sparse_categorical_accuracy: 1.0000
# Epoch 96/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0018 - sparse_categorical_accuracy: 1.0000
# Epoch 97/100
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0050 - sparse_categorical_accuracy: 1.0000
# Epoch 98/100
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0012 - sparse_categorical_accuracy: 1.0000
# Epoch 99/100
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0279 - sparse_categorical_accuracy: 0.9867
# Epoch 100/100
# 3/3 [==============================] - 0s 19ms/step - loss: 6.7797e-04 - sparse_categorical_accuracy: 1.0000

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print("Test accuracy: {}".format(test_accuracy))
# Out:
# 3/3 [==============================] - 0s 10ms/step - loss: 0.3375 - sparse_categorical_accuracy: 0.9733
# Test accuracy: 0.9733333587646484

# %%
# The '.h5' extension indicates that the model should be saved to HDF5.
model.save('M5_model.h5')

# %%
# Carregando o modelo
new_model = tf.keras.models.load_model('/content/M5_model.h5')

# %% [markdown]
# Como fazer previsões?

# %%
print(X_test[20],'Classe:', y_test.iloc[20])
# Out:
# [1.21021821 0.05573135 0.47941516 0.36244635] Classe: 2

# %%
np.argmax(new_model.predict(X_test[20].reshape(-1, 4))[0])
# Out:
# 2
